# %%
import bbi

# %%
epig_path = "/mnt/beegfs/userdata/j_wang/Algorithm_Resources/dig/Epigenomics/E012-H3K4me1.pval.signal.bigwig"

# %%
epig_fd = bbi.open(epig_path)

# %%
epig_fd.schema
# Out:
# {'name': 'bedGraph',
#  'comment': '',
#  'columns': ['chrom', 'start', 'end', 'value'],
#  'dtypes': {'chrom': 'object',
#   'start': 'uint32',
#   'end': 'uint32',
#   'value': 'float32'},
#  'description': {'chrom': 'Reference sequence chromosome or scaffold',
#   'start': 'Start position in chromosome',
#   'end': 'End position in chromosome',
#   'value': 'Data value'}}

# %%
epig_fd.chromsizes
# Out:
# {'chr1': 249250621,
#  'chr10': 135534747,
#  'chr11': 135006516,
#  'chr12': 133851895,
#  'chr13': 115169878,
#  'chr14': 107349540,
#  'chr15': 102531392,
#  'chr16': 90354753,
#  'chr17': 81195210,
#  'chr18': 78077248,
#  'chr19': 59128983,
#  'chr2': 243199373,
#  'chr20': 63025520,
#  'chr21': 48129895,
#  'chr22': 51304566,
#  'chr3': 198022430,
#  'chr4': 191154276,
#  'chr5': 180915260,
#  'chr6': 171115067,
#  'chr7': 159138663,
#  'chr8': 146364022,
#  'chr9': 141213431,
#  'chrM': 16571,
#  'chrX': 155270560,
#  'chrY': 59373566}

# %%
epig_fd.info
# Out:
# {'version': 4,
#  'isCompressed': True,
#  'isSwapped': 0,
#  'primaryDataSize': 370302177,
#  'zoomLevels': 10,
#  'chromCount': 25,
#  'summary': {'basesCovered': 3094322481,
#   'sum': 1490155077.6656675,
#   'mean': 0.48157717458850324,
#   'min': 0.0,
#   'max': 532.7186279296875,
#   'std': 1.120055959589847}}

# %%
epig_fd.fetch_intervals('chr1', 1, 100000)
# Out:
#    chrom  start     end    value
# 0   chr1      1   10117  0.15904
# 1   chr1  10117   10131  0.48031
# 2   chr1  10131   10164  0.39292
# 3   chr1  10164   10166  0.25747
# 4   chr1  10166   10203  0.17205
# 5   chr1  10203   10238  0.11611
# 6   chr1  10238   10297  0.07868
# 7   chr1  10297   10300  0.11611
# 8   chr1  10300   10341  0.17205
# 9   chr1  10341   10361  0.11611
# 10  chr1  10361   10394  0.17205
# 11  chr1  10394   10396  0.25747
# 12  chr1  10396   10433  0.39292
# 13  chr1  10433   10437  0.48031
# 14  chr1  10437   10449  0.39292
# 15  chr1  10449   10467  0.25747
# 16  chr1  10467   10468  0.07405
# 17  chr1  10468   10571  0.12443
# 18  chr1  10571   14715  0.15904
# 19  chr1  14715   14838  0.48031
# 20  chr1  14838   14945  0.39292
# 21  chr1  14945   15030  0.12443
# 22  chr1  15030   16147  0.15904
# 23  chr1  16147   16156  0.12443
# 24  chr1  16156   16187  0.07405
# 25  chr1  16187   16233  0.04510
# 26  chr1  16233   16324  0.17205
# ...
